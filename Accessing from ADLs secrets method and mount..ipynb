# %%
# %fs ls abfss://test@gen2x.dfs.core.windows.net
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.services.SimpleKeyProvider.getStorageAccountKey(SimpleKeyProvider.java:52)
# ...

# %%
spark.conf.set (
    "fs.azure.account.key.gen2x.dfs.core.windows.net",
    "11a9L2I1y185dSOpNtuRrOiPTOhzhxP2A1GUm++I3AbezB3AqMRLOskD5q91ofZavhBxpU018s17+AStRVjC3g=="
)

# %%
spark.read.csv('abfss://test@gen2x.dfs.core.windows.net/CONY_intraday.csv')
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string]

# %%
spark.conf.set (
    "fs.azure.account.key.gen2x.dfs.core.windows.net",
    dbutils.secrets.get(scope='gen2x', key="gen2x")
)

#create data bricks scope 
#create azure keyvault service and add account key there

# %%
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-2533677099504032>, line 1
# ----> 1 dbutils.fs.unmount("/mnt/datamount")
#
# File /databricks/python_shell/dbruntime/dbutils.py:362, in DBUtils.FSHandler.prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     360 exc.__context__ = None
#     361 exc.__cause__ = None
# --> 362 raise exc
#
# ExecutionError: An error occurred while calling o396.unmount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory not mounted: /mnt/datamount; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory not mounted: /mnt/datamount
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:135)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:69)
# ...

# %%
dbutils.secrets.get(scope="gen2x",key="gen2x"),
# Out:
# ('[REDACTED]',)

# %%
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-2533677099504029>, line 1
# ----> 1 dbutils.fs.mount(
#       2   source = "abfss://test@gen2x.dfs.core.windows.net/CONY_intraday.csv",
#       3   mount_point = "/mnt/datamount",
#       4   extra_configs = configs)
#
# File /databricks/python_shell/dbruntime/dbutils.py:362, in DBUtils.FSHandler.prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     360 exc.__context__ = None
#     361 exc.__cause__ = None
# --> 362 raise exc
#
# ExecutionError: An error occurred while calling o396.mount.
# : java.lang.NullPointerException
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.oauth2.AzureADAuthenticator.getTokenCall(AzureADAuthenticator.java:320)
# ...
