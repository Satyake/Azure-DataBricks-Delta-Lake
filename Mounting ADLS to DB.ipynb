# %%
spark.conf.set("fs.azure.account.auth.type.deltalake63.dfs.core.windows.net", "SAS")
spark.conf.set("fs.azure.sas.token.provider.type.deltalake63.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider")
spark.conf.set("fs.azure.sas.fixed.token.deltalake63.dfs.core.windows.net", "sv=2022-11-02&ss=bfqt&srt=sco&sp=rwdlacupyx&se=2024-02-23T12:45:38Z&st=2024-02-23T04:45:38Z&spr=https&sig=w0D4svNjGIbH%2FsLnG7oJ%2Fw5QRHOOXYAvr%2F%2FdLqDIGDA%3D")

# %%
spark.conf.set("spark.databricks.delta.schema.autoMerge.enabled", "false")

# %%
spark.read.csv("abfss://bronze@deltalake63.dfs.core.windows.net/order_items.csv",header=True)
# Out:
# DataFrame[ORDER_ID: string, LINE_ITEM_ID: string, PRODUCT_ID: string, UNIT_PRICE: string, QUANTITY: string]

# %%
application_id="3b9011d8-0299-42d9-8924-a2e569353650"
tenant_id="a287f42c-46eb-424f-ab40-cd784a7b423c"
secret="WjA8Q~FylyeigAcpaYTGHjelXXjRzbmu52d2jby2"

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
          "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
          "fs.azure.account.oauth2.client.id": application_id,
          "fs.azure.account.oauth2.client.secret": secret,
          "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"}

# Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(
  source = "abfss://bronze@deltalake63.dfs.core.windows.net/",
  mount_point = "/mnt/bronze",
  extra_configs = configs)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-2853628802681111>, line 8
#       1 configs = {"fs.azure.account.auth.type": "OAuth",
#       2           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
#       3           "fs.azure.account.oauth2.client.id": application_id,
#       4           "fs.azure.account.oauth2.client.secret": secret,
#       5           "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"}
#       7 # Optionally, you can add <directory-name> to the source URI of your mount point.
# ----> 8 dbutils.fs.mount(
#       9   source = "abfss://bronze@deltalake63.dfs.core.windows.net/",
#      10   mount_point = "/mnt/bronze",
#      11   extra_configs = configs)
#
# ...

# %%
display(dbutils.fs.mounts())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
spark.read.csv('/mnt/bronze/order_items.csv',header=True).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.unmount('/mnt/bronze')
# Out:
# /mnt/bronze has been unmounted.
# True

# %%
secret=dbutils.secrets.get(scope="db-kv001", key="secret")
application=dbutils.secrets.get(scope="db-kv001", key="application-id")
tenant=dbutils.secrets.get(scope="db-kv001", key="tenant")
# Out:
# '[REDACTED]'

# %%
for i in dbutils.secrets.get(scope="db-kv001", key="secret"):
    print(i)
# Out:
# W
# j
# A
# 8
# Q
# ~
# F
# y
# l
# y
# e
# i
# g
# A
# c
# p
# a
# Y
# T
# G
# H
# j
# e
# l
# X
# X
# j
# R
# z
# b
# m
# u
# 5
# 2
# d
# 2
# j
# b
# y
# 2
